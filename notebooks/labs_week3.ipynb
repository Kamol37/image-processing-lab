# %%
import cv2

# %%
img = cv2.imread("/Users/230696/Downloads/brain.png", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (640, 640, 3)

# %%
bgr_image = img[...,0:3]   # bgr_image: extracts the first three channels of the image (Blue, Green, Red).
alpha_image = img[...,-1]  # alpha_image: extracts the last channel, which represents the alpha (transparency) channel.

rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image); plt.title("RGB")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       2 alpha_image = img[...,-1]  # alpha_image: extracts the last channel, which represents the alpha (transparency) channel.
#       4 rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
# ----> 5 plt.imshow(rgb_image); plt.title("RGB")
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'imshow'

# %%
plt.imshow(alpha_image, cmap='gray'); plt.title("Alpha");

# %%
img = cv2.imread("/Users/230696/Downloads/brain.png", cv2.IMREAD_UNCHANGED)
img.shape

# %%
bgr_image = img[...,0:3]
alpha_image = img[...,-1]

rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image); plt.title("RGB");

# %%
plt.imshow(alpha_image, cmap='gray'); plt.title("Alpha");

# %%
import numpy as np
#SQUARE
square = np.zeros((300, 300), np.uint8)
cv2.rectangle(square, (50, 50), (250, 250), 255, -1)
#ELLIPSE
ellipse = np.zeros((300, 300), np.uint8)
cv2.ellipse(ellipse, (150, 150), (150, 150), 30, 0, 180, 255, -1)

plt.subplot(121);plt.imshow(square,cmap='gray');plt.title("square");
plt.subplot(122);plt.imshow(ellipse,cmap='gray');plt.title("ellipse");

# %%
import cv2
import numpy as np
import matplotlib as plt

# %%
img = cv2.imread("/Users/230696/Downloads/brain.png")
print (image.shape)
translation_matrix = np.float32([[1,0,100],[0,1,50]])
translated_image = cv2.warpAffine(image, translation_matrix, (image.shape[1], image.shape[0]))
print (translated_image.shape)

# %%
plt.imshow(cv2.cvtColor(translated_image, cv2.COLOR_BGR2RGB))
plt.title('translated image')
plt.axis('off')
plt.show()

# %%
(h,w)=image.shape[:2]
center = (w//2,h//2)
rotation_matrix = cv2.getRotationMatrix2D(center, 45,1.0)

rotated_image = cv2.warpAffine(image, rotation_matrix, (w,h))

plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
plt.title('rotated image 45 degrees')
plt.axis('off')
plt.show()
